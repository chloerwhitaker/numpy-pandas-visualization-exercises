# %% [markdown]
# ## Exercises I.

# %% [markdown]
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
#
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore
#
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.
#
# 4. Use your function to obtain a connection to the employees database.

# %%
import pandas as pd

# %%
def get_db_url(db_name):
    from env import host, user, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
sql = '''
SELECT * 
from employees
'''

# %%
url = get_db_url("employees")

df = pd.read_sql(sql, url)
df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %% [markdown]
# 5. Once you have successfully run a query:
#
#     a. Intentionally make a typo in the database url. What kind of error message do you see?
#
#     b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
# a. ValueError: invalid literal for int() with base 10:
# b. ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'from departments' at line 1")
#[SQL: 
#    SELECT  from departments
#]
#(Background on this error at: http://sqlalche.me/e/14/f405)

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
employees_sql = '''
SELECT *
from employees
'''
titles_sql = '''
SELECT *
from titles
'''

# %%
url = get_db_url("employees")

employees = pd.read_sql(employees_sql, url)
employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
titles = pd.read_sql(titles_sql, url)
titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees.shape
# Out:
# (300024, 6)

# %%
titles.shape
# Out:
# (443308, 4)

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
titles.nunique() #7
# Out:
# emp_no       300024
# title             7
# from_date      6393
# to_date        5888
# dtype: int64

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
titles.sort_values(by='to_date').head(1)
# Out:
#        emp_no     title   from_date     to_date
# 16064   20869  Engineer  1985-02-17  1985-03-01

# %%
# 1985-03-01

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
titles.sort_values(by='to_date').tail(1)
# Out:
#         emp_no     title   from_date     to_date
# 443307  499999  Engineer  1997-11-30  9999-01-01

# %%
# 9999-01-01

# %%
titles_sql = '''
SELECT *
FROM titles where to_date != '9999-01-01'
'''
url = get_db_url("employees")
titles = pd.read_sql(titles_sql, url)

# %%
titles.sort_values(by='to_date').tail(1)
# Out:
#         emp_no            title   from_date     to_date
# 167151  446732  Senior Engineer  1992-11-10  2002-08-01

# %%
# 2002-08-01

# %%
# or just using SQL

titles_sql = '''
SELECT max(to_date) FROM titles WHERE to_date != '9999-01-01'
'''
url = get_db_url("employees")
max_titles_to_date = pd.read_sql(titles_sql, url)
max_titles_to_date.head()
# Out:
#   max(to_date)
# 0   2002-08-01

# %%
# 2002-08-01

# %% [markdown]
# ## Exercises II
# 1. Copy the users and roles DataFrames from the examples above.

# %%
import numpy as np


users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='right')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames

# %%
users.merge(roles, left_on='role_id', right_on='id', how='outer')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
# error - KeyError: 'id'
# can't join w/o foreign keys because there's nothing to match w/0 foreign keys
# users.drop(columns='role_id').merge(roles.drop(columns='id'), how='inner', left_on='role_id', right_on='id')

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg')

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'engine_displacement', 'year', 'cylinders',
#        'transmission', 'wheel_drive', 'city_mpg', 'highway_mpg', 'fl',
#        'class'],
#       dtype='object')

# %%
mpg.rename(columns={'displ':'engine_displacement', 'cyl':'cylinders', 'trans':'transmission', 'drv':'wheel_drive', 'cty':'city_mpg', 'hwy':'highway_mpg'}, inplace=True)
mpg
# Out:
#     manufacturer   model  engine_displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
#     wheel_drive  city_mpg  highway_mpg fl    class
# ...

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#        engine_displacement         year   cylinders    city_mpg  highway_mpg
# count           234.000000   234.000000  234.000000  234.000000   234.000000
# mean              3.471795  2003.500000    5.888889   16.858974    23.440171
# std               1.291959     4.509646    1.611534    4.255946     5.954643
# min               1.600000  1999.000000    4.000000    9.000000    12.000000
# 25%               2.400000  1999.000000    4.000000   14.000000    18.000000
# 50%               3.300000  2003.500000    6.000000   17.000000    24.000000
# 75%               4.600000  2008.000000    8.000000   19.000000    27.000000
# max               7.000000  2008.000000    8.000000   35.000000    44.000000

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   manufacturer         234 non-null    object
#  1   model                234 non-null    object
#  2   engine_displacement  234 non-null    float64
#  3   year                 234 non-null    int64
#  4   cylinders            234 non-null    int64
#  5   transmission         234 non-null    object
#  6   wheel_drive          234 non-null    object
#  7   city_mpg             234 non-null    int64
#  8   highway_mpg          234 non-null    int64
#  9   fl                   234 non-null    object
#  10  class                234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
len(mpg.manufacturer)
# Out:
# 234

# %%
len(mpg.manufacturer.unique())
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
len(mpg.model.unique())
# can also use .value_counts()
# Out:
# 38

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway_mpg - mpg.city_mpg
mpg
# Out:
#     manufacturer   model  engine_displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
# ...

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.city_mpg + mpg.highway_mpg)/2
mpg
# Out:
#     manufacturer   model  engine_displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
# ...

# %%
# another way using axis:
# mpg['average_mileage'] = mpg[['city_mpg', 'highway_mpg']].mean(axis = 1)

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
# mpg.is_automatic = mpg.transmission.apply(lambada value : value[0] == 'a')
# mpg.head()

# %%
mpg.is_automatic = np.where(mpg.transmission.str.contains('auto'), True, False)
mpg
# Out:
#     manufacturer   model  engine_displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
# ...

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg[mpg.average_mileage == max(mpg.average_mileage)]
# Out:
#     manufacturer       model  engine_displacement  year  cylinders  \
# 222   volkswagen  new beetle                  1.9  1999          4
#
#     transmission wheel_drive  city_mpg  highway_mpg fl       class  \
# 222   manual(m5)           f        35           44  d  subcompact
#
#      mileage_difference  average_mileage  is_automatic
# 222                   9             39.5         False

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.average_mileage.mean() #need to groupby is_automatic 1st
# Out:
# 20.14957264957265

# %%
mpg.groupby(by='is_automatic').average_mileage.mean() # the manual gets better mpg
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %% [markdown]
# ### Exercises III
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
def get_db_url(db_name):
    from env import host,user,password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
url = get_db_url('chipotle')

# %%
sql = '''
SELECT *
FROM orders
'''

# %%
chipotle = pd.read_sql(sql, url)
chipotle.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %% [markdown]
# 2. What is the total price for each order?

# %%
chipotle.item_price = chipotle.item_price.replace('[\$]', '', regex=True).astype(float)

chipotle.head(10)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
# 5   6         3         1                           Chicken Bowl
# 6   7         3         1                          Side of Chips
# 7   8         4         1                          Steak Burrito
# 8   9         4         1                       Steak Soft Tacos
# 9  10         5         1                          Steak Burrito
#
#                                                                           choice_description  \
# 0                                                                                        nan
# ...

# %%
# if the quantity wasn't already considered in the 'item_price' column, could handle like this:

# chipotle['new_item_price'] = chipotle.item_price * chipotle.quantity
# chipotle.head()

# %%
order_total = chipotle.groupby(by='order_id')['item_price'].sum()
order_total.head()
# Out:
# order_id
# 1    11.56
# 2    16.98
# 3    12.67
# 4    21.00
# 5    13.70
# Name: item_price, dtype: float64

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
most_popular_items = chipotle.groupby(by='item_name')['item_name'].count().nlargest(3, keep='all')

most_popular_items
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: item_name, dtype: int64

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
chipotle.groupby('item_name').item_price.sum().nlargest(1, keep='all')
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
emp_title = employees.merge(titles, left_on='emp_no', right_on='emp_no', how='inner')

emp_title
# Out:
#         emp_no  birth_date first_name  last_name gender   hire_date  \
# 0        10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 1        10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 2        10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 3        10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 4        10009  1952-04-19     Sumant       Peac      F  1985-02-18
# ...        ...         ...        ...        ...    ...         ...
# 203179  499992  1960-10-12     Siamak   Salverda      F  1987-05-10
# 203180  499994  1952-02-26      Navin    Argence      F  1990-04-24
# 203181  499996  1953-03-07       Zito       Baaz      M  1990-09-27
# 203182  499997  1961-08-03    Berhard     Lenart      M  1986-04-21
# 203183  499998  1956-09-05   Patricia    Breugel      M  1993-10-13
#
#                      title   from_date     to_date
# 0                 Engineer  1986-12-01  1995-12-01
# ...

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_title.groupby(by=['title'])['hire_date'].max()
# Out:
# title
# Assistant Engineer    1999-11-16
# Engineer              2000-01-28
# Manager               1991-08-17
# Senior Engineer       1999-12-11
# Senior Staff          2000-01-08
# Staff                 2000-01-02
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
def get_db_url(db_name):
    from env import host, user, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'
    
sql = '''
SELECT * 
from departments
'''   
url = get_db_url("employees")
departments = pd.read_sql(sql, url)
departments
# Out:
#   dept_no           dept_name
# 0    d009    Customer Service
# 1    d005         Development
# 2    d002             Finance
# 3    d003     Human Resources
# 4    d001           Marketing
# 5    d004          Production
# 6    d006  Quality Management
# 7    d008            Research
# 8    d007               Sales

# %%
def get_db_url(db_name):
    from env import host, user, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

sql = '''
SELECT * 
from dept_emp
'''   
url = get_db_url("employees")
dept_emp = pd.read_sql(sql, url)
dept_emp.head()
# Out:
#    emp_no dept_no   from_date     to_date
# 0   10001    d005  1986-06-26  9999-01-01
# 1   10002    d007  1996-08-03  9999-01-01
# 2   10003    d004  1995-12-03  9999-01-01
# 3   10004    d004  1986-12-01  9999-01-01
# 4   10005    d003  1989-09-12  9999-01-01

# %%
dept_with_dept_emp = departments.merge(dept_emp, left_on='dept_no', right_on='dept_no', how='inner')
dept_with_dept_emp.head()
# Out:
#   dept_no         dept_name  emp_no   from_date     to_date
# 0    d009  Customer Service   10011  1990-01-22  1996-11-09
# 1    d009  Customer Service   10038  1989-09-20  9999-01-01
# 2    d009  Customer Service   10049  1992-05-04  9999-01-01
# 3    d009  Customer Service   10060  1992-11-11  9999-01-01
# 4    d009  Customer Service   10088  1992-03-21  9999-01-01

# %%
titles_by_dept = dept_with_dept_emp.merge(titles, left_on='emp_no', right_on='emp_no', how='inner')
titles_by_dept.head()
# Out:
#   dept_no         dept_name  emp_no from_date_x   to_date_x  title  \
# 0    d009  Customer Service   10011  1990-01-22  1996-11-09  Staff
# 1    d009  Customer Service   10038  1989-09-20  9999-01-01  Staff
# 2    d009  Customer Service   10049  1992-05-04  9999-01-01  Staff
# 3    d009  Customer Service   10060  1992-11-11  9999-01-01  Staff
# 4    d007             Sales   10060  1989-05-28  1992-11-11  Staff
#
#   from_date_y   to_date_y
# 0  1990-01-22  1996-11-09
# 1  1989-09-20  1996-09-20
# 2  1992-05-04  2000-05-04
# 3  1989-05-28  1996-05-28
# 4  1989-05-28  1996-05-28

# %%
pd.crosstab(titles_by_dept.title, titles_by_dept.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               230         5936        0                0
# Engineer                        1735        42458        0                0
# Manager                            3            1        1                1
# Senior Engineer                  237         5962        0                0
# Senior Staff                    1576          162     1489             1431
# Staff                          12248         1109    10730            10926
# Technique Leader                  68         1566        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        4903                1398       301      0
# Engineer                    0       36324               10108      2156      0
# Manager                     1           3                   3         1      1
# ...
