# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
#             y=x2−x+2
#    You'll need to write the code that generates the x and y points.
#
#    Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt

# %%
x1 = list(range(20))
y1 = [(x**2)-x+2 for x in x]

plt.figure(figsize = (8,6))
plt.plot(x,y, color = 'b', ls = '--', marker = 'o', ms = '5')
plt.annotate('This is the origin', (0, 0), (5, 300), arrowprops = dict());
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-2d6f208eda55> in <module>
#       3
#       4 plt.figure(figsize = (8,6))
# ----> 5 plt.plot(x,y, color = 'b', ls = '--', marker = 'o', ms = '5')
#       6 plt.annotate('This is the origin', (0, 0), (5, 300), arrowprops = dict());
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (20,) and (30,)

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
#         y = √x
#         y = x3
#         y = 2x
#         y = 1/(x+1)
#
#    You can use functions from the math module to help implement some of the equations above.

# %%
import math

# %%
x = list(range(20))
y1 = [math.sqrt(x) for x in x]
y2 = [x**3 for x in x]
y3 = [2**x for x in x]
y4 = [1/(x+1) for x in x]

# %%
plt.plot(x,y1, color = 'b', ls = '--', marker = 'o', ms = '5');

# %%
plt.plot(x,y2, color = 'b', ls = '--', marker = 'o', ms = '5');

# %%
plt.plot(x,y3, color = 'b', ls = '--', marker = 'o', ms = '5');

# %%
plt.plot(x,y4, color = 'b', ls = '--', marker = 'o', ms = '5');

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.subplot(2,2,1)
plt.plot(x,y1, color = 'b', ls = '--', marker = 'o', ms = '5');
plt.title("$\sqrt{x}$")

plt.subplot(2,2,2)
plt.plot(x,y2, color = 'b', ls = '--', marker = 'o', ms = '5');
plt.title("$y=X^3$")

plt.subplot(2,2,3)
plt.plot(x,y3, color = 'b', ls = '--', marker = 'o', ms = '5');
plt.title("$y=2^X$")

plt.subplot(2,2,4)
plt.plot(x,y4, color = 'b', ls = '--', marker = 'o', ms = '5');
plt.title("$y=\dfrac{1}{x+1}$")

plt.suptitle('Math Functions', fontsize = 16)

plt.tight_layout();

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.plot(x,y1, color = 'blue', ls = '--', marker = 'o', ms = '5')
plt.plot(x,y2, color = 'red', ls = '--', marker = 'o', ms = '5')
plt.plot(x,y3, color = 'purple', ls = '--', marker = 'o', ms = '5')
plt.plot(x,y4, color = 'green', ls = '--', marker = 'o', ms = '5')

plt.ylim(0,10)

plt.legend(["$y=\sqrt{x}$", "$y=X^3$", "$y=2^X$", "$y=\dfrac{1}{x+1}$"])

plt.title('Plot of 4 math equations.');
